# %% [markdown]
# ## 1️⃣ Instalación de Dependencias (si es necesario)

# %%
# Instalar TensorFlow/Keras si no está disponible
import subprocess
import sys

try:
    import tensorflow as tf
    print(f"✅ TensorFlow {tf.__version__} ya instalado")
except ImportError:
    print("⚙️ Instalando TensorFlow...")
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'tensorflow', '-q'])
    import tensorflow as tf
    print(f"✅ TensorFlow {tf.__version__} instalado correctamente")

try:
    import keras
    print(f"✅ Keras {keras.__version__} disponible")
except ImportError:
    print("⚙️ Instalando Keras...")
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'keras', '-q'])
    import keras
    print(f"✅ Keras {keras.__version__} instalado")
# Out:
# ✅ TensorFlow 2.20.0 ya instalado
# ✅ Keras 3.12.0 disponible

# %% [markdown]
# ---
#
# ## 2️⃣ Importación de Librerías

# %%
# Manipulación de datos
import pandas as pd
import numpy as np
from pathlib import Path
from datetime import datetime
import json
import warnings
warnings.filterwarnings('ignore')

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# Deep Learning
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Preprocesamiento
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Configuración
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

# Reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

print(f"✅ Librerías importadas correctamente")
print(f"   TensorFlow: {tf.__version__}")
print(f"   Keras: {keras.__version__}")
print(f"   GPU disponible: {tf.config.list_physical_devices('GPU')}")
# Out:
# ✅ Librerías importadas correctamente
#    TensorFlow: 2.20.0
#    Keras: 3.12.0
#    GPU disponible: []

# %% [markdown]
# ---
#
# ## 3️⃣ Carga de Datos Integrados

# %%
# Configurar rutas
BASE_DIR = Path('/home/els4nchez/Videos/TECH')
DATA_DIR = BASE_DIR / 'data'
UNIFICACION_DIR = BASE_DIR / 'unificacion'
DATA_PROCESADO_DIR = UNIFICACION_DIR / 'datos_procesados'
FIGURAS_DIR = UNIFICACION_DIR / 'figuras'
MODELOS_DIR = UNIFICACION_DIR / 'modelos'

# Crear directorio de modelos si no existe
MODELOS_DIR.mkdir(parents=True, exist_ok=True)

print("📂 Cargando dataset integrado...\n")

# Cargar datos integrados (del notebook 06)
ruta_datos = DATA_PROCESADO_DIR / 'datos_integrados_precios_sentimientos.csv'
df = pd.read_csv(ruta_datos, index_col=0, parse_dates=True)

print(f"✅ Dataset cargado: {df.shape[0]:,} días × {df.shape[1]} variables")
print(f"   Rango: {df.index.min().strftime('%Y-%m-%d')} → {df.index.max().strftime('%Y-%m-%d')}")
print(f"\n📊 Columnas disponibles:")
print(f"   {list(df.columns)}")
# Out:
# 📂 Cargando dataset integrado...
#
# ✅ Dataset cargado: 2,273 días × 23 variables
#    Rango: 2016-01-03 → 2025-10-31
#
# 📊 Columnas disponibles:
#    ['Open', 'High', 'Low', 'Close', 'Volume', 'Returns', 'Volatility_30', 'outlier_iqr', 'z_score', 'outlier_zscore', 'anomaly_score', 'outlier_iforest', 'outlier_count', 'outlier_consensus', 'sentiment_numeric', 'sentiment', 'sentiment_score', 'num_noticias', 'sentiment_ma7', 'sentiment_ma30', 'sentiment_extreme', 'has_outlier', 'outlier_AND_extreme_sentiment']
#
# 🔍 Valores faltantes por columna:
# Returns            1
# Volatility_30     21
# sentiment_ma7      6
# sentiment_ma30    29
# dtype: int64
#                 Open      High       Low     Close    Volume   Returns  \
# 2016-01-03  1062.341  1066.321  1061.729  1063.059   1.61136       NaN
# 2016-01-04  1063.059  1083.488  1062.239  1072.979  76.56875  0.009288
# 2016-01-05  1072.990  1082.048  1072.629  1077.632  72.43959  0.004327
#
#             Volatility_30  outlier_iqr   z_score  outlier_zscore  ...  \
# 2016-01-03            NaN        False  1.195449           False  ...
# 2016-01-04            NaN        False  1.179487           False  ...
# 2016-01-05            NaN        False  1.172000           False  ...
#
#             outlier_consensus  sentiment_numeric  sentiment  sentiment_score  \
# 2016-01-03              False           0.083333   0.036220         0.813113
# 2016-01-04              False           0.153846   0.104399         0.835821
# 2016-01-05              False          -0.263158  -0.226055         0.776322
#
#             num_noticias  sentiment_ma7  sentiment_ma30  sentiment_extreme  \
# 2016-01-03            12            NaN             NaN              False
# 2016-01-04            13            NaN             NaN              False
# 2016-01-05            19            NaN             NaN              False
#
#             has_outlier  outlier_AND_extreme_sentiment
# 2016-01-03        False                          False
# 2016-01-04        False                          False
# 2016-01-05        False                          False
#
# [3 rows x 23 columns]

# %% [markdown]
# ---
#
# ## 4️⃣ Preparación de Features

# %%
# Seleccionar features para los modelos

# Features técnicos base (sin sentimiento)
features_base = [
    'Open', 'High', 'Low', 'Close',
    'Returns',
    'Volatility_30'
]

# Features con sentimiento
features_sentiment = features_base + [
    'sentiment',
    'sentiment_ma7',
    'sentiment_ma30'
]

# Variable objetivo
target = 'Close'

print("📋 CONFIGURACIÓN DE FEATURES")
print("=" * 80)
print(f"\n🔹 Modelo Base (sin sentimiento):")
print(f"   Features: {features_base}")
print(f"   Total: {len(features_base)} variables")

print(f"\n🔸 Modelo con Sentimiento:")
print(f"   Features: {features_sentiment}")
print(f"   Total: {len(features_sentiment)} variables")

print(f"\n🎯 Variable Objetivo: {target}")

# Eliminar filas con NaN en features críticos (usar solo features_sentiment ya que incluye todas las columnas necesarias)
df_clean = df[features_sentiment].dropna()

print(f"\n🧹 Después de limpieza:")
print(f"   Datos válidos: {len(df_clean):,} días")
print(f"   Datos eliminados: {len(df) - len(df_clean):,} días")
# Out:
# 📋 CONFIGURACIÓN DE FEATURES
# ================================================================================
#
# 🔹 Modelo Base (sin sentimiento):
#    Features: ['Open', 'High', 'Low', 'Close', 'Returns', 'Volatility_30']
#    Total: 6 variables
#
# 🔸 Modelo con Sentimiento:
#    Features: ['Open', 'High', 'Low', 'Close', 'Returns', 'Volatility_30', 'sentiment', 'sentiment_ma7', 'sentiment_ma30']
#    Total: 9 variables
#
# 🎯 Variable Objetivo: Close
#
# 🧹 Después de limpieza:
#    Datos válidos: 2,238 días
#    Datos eliminados: 35 días

# %% [markdown]
# ---
#
# ## 5️⃣ División Temporal de Datos (Train/Val/Test)

# %%
# División temporal: 60% train, 20% validation, 20% test
train_size = int(len(df_clean) * 0.60)
val_size = int(len(df_clean) * 0.20)
test_size = len(df_clean) - train_size - val_size

# Dividir datos
df_train = df_clean.iloc[:train_size]
df_val = df_clean.iloc[train_size:train_size + val_size]
df_test = df_clean.iloc[train_size + val_size:]

print("📊 DIVISIÓN TEMPORAL DE DATOS")
print("=" * 80)
print(f"\n🔹 Train (60%):")
print(f"   Filas: {len(df_train):,}")
print(f"   Rango: {df_train.index.min().strftime('%Y-%m-%d')} → {df_train.index.max().strftime('%Y-%m-%d')}")

print(f"\n🔸 Validation (20%):")
print(f"   Filas: {len(df_val):,}")
print(f"   Rango: {df_val.index.min().strftime('%Y-%m-%d')} → {df_val.index.max().strftime('%Y-%m-%d')}")

print(f"\n🔺 Test (20%):")
print(f"   Filas: {len(df_test):,}")
print(f"   Rango: {df_test.index.min().strftime('%Y-%m-%d')} → {df_test.index.max().strftime('%Y-%m-%d')}")

print(f"\n✅ Total: {len(df_clean):,} días")

# Visualizar división
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df_train.index,
    y=df_train['Close'],
    mode='lines',
    name='Train (60%)',
    line=dict(color='blue')
))

fig.add_trace(go.Scatter(
    x=df_val.index,
    y=df_val['Close'],
    mode='lines',
    name='Validation (20%)',
    line=dict(color='orange')
))

fig.add_trace(go.Scatter(
    x=df_test.index,
    y=df_test['Close'],
    mode='lines',
    name='Test (20%)',
    line=dict(color='green')
))

fig.update_layout(
    title='División Temporal de Datos: Train / Validation / Test',
    xaxis_title='Fecha',
    yaxis_title='Precio de Cierre (USD)',
    template='plotly_white',
    height=500
)

fig.show()
# Out:
# 📊 DIVISIÓN TEMPORAL DE DATOS
# ================================================================================
#
# 🔹 Train (60%):
#    Filas: 1,342
#    Rango: 2016-02-02 → 2022-01-15
#
# 🔸 Validation (20%):
#    Filas: 447
#    Rango: 2022-01-17 → 2024-05-01
#
# 🔺 Test (20%):
#    Filas: 449
#    Rango: 2024-05-02 → 2025-10-14
#
# ✅ Total: 2,238 días

# %% [markdown]
# ---
#
# ## 6️⃣ Normalización de Datos

# %%
# Crear escaladores (fit solo con datos de entrenamiento)
scaler_base = MinMaxScaler()
scaler_sentiment = MinMaxScaler()

# Escalar features base
X_train_base_scaled = scaler_base.fit_transform(df_train[features_base])
X_val_base_scaled = scaler_base.transform(df_val[features_base])
X_test_base_scaled = scaler_base.transform(df_test[features_base])

# Escalar features con sentimiento
X_train_sent_scaled = scaler_sentiment.fit_transform(df_train[features_sentiment])
X_val_sent_scaled = scaler_sentiment.transform(df_val[features_sentiment])
X_test_sent_scaled = scaler_sentiment.transform(df_test[features_sentiment])

# Escalar target (Close) para desnormalizar predicciones
scaler_target = MinMaxScaler()
y_train_scaled = scaler_target.fit_transform(df_train[[target]])
y_val_scaled = scaler_target.transform(df_val[[target]])
y_test_scaled = scaler_target.transform(df_test[[target]])

print("✅ Normalización completada (MinMaxScaler)")
print(f"\n📊 Rangos de normalización:")
print(f"   Features base: [{X_train_base_scaled.min():.3f}, {X_train_base_scaled.max():.3f}]")
print(f"   Features sentiment: [{X_train_sent_scaled.min():.3f}, {X_train_sent_scaled.max():.3f}]")
print(f"   Target: [{y_train_scaled.min():.3f}, {y_train_scaled.max():.3f}]")
# Out:
# ✅ Normalización completada (MinMaxScaler)
#
# 📊 Rangos de normalización:
#    Features base: [0.000, 1.000]
#    Features sentiment: [0.000, 1.000]
#    Target: [0.000, 1.000]

# %% [markdown]
# ---
#
# ## 7️⃣ Creación de Secuencias para LSTM

# %%
def create_sequences(X, y, seq_length=60):
    """
    Crea secuencias para LSTM.
    
    Args:
        X: Features normalizados (array 2D)
        y: Target normalizado (array 1D o 2D)
        seq_length: Longitud de la secuencia (lookback window)
    
    Returns:
        X_seq: Secuencias de features (3D: samples × seq_length × features)
        y_seq: Targets correspondientes (1D)
    """
    X_seq, y_seq = [], []
    
    for i in range(seq_length, len(X)):
        X_seq.append(X[i - seq_length:i])
        y_seq.append(y[i])
    
    return np.array(X_seq), np.array(y_seq)

# Configuración
SEQ_LENGTH = 60  # 60 días de lookback

print(f"🔧 Creando secuencias (lookback={SEQ_LENGTH} días)...\n")

# Crear secuencias para modelo BASE
X_train_base_seq, y_train_seq = create_sequences(X_train_base_scaled, y_train_scaled, SEQ_LENGTH)
X_val_base_seq, y_val_seq = create_sequences(X_val_base_scaled, y_val_scaled, SEQ_LENGTH)
X_test_base_seq, y_test_seq = create_sequences(X_test_base_scaled, y_test_scaled, SEQ_LENGTH)

# Crear secuencias para modelo con SENTIMIENTO
X_train_sent_seq, _ = create_sequences(X_train_sent_scaled, y_train_scaled, SEQ_LENGTH)
X_val_sent_seq, _ = create_sequences(X_val_sent_scaled, y_val_scaled, SEQ_LENGTH)
X_test_sent_seq, _ = create_sequences(X_test_sent_scaled, y_test_scaled, SEQ_LENGTH)

print("✅ Secuencias creadas")
print("\n📊 MODELO BASE (sin sentimiento):")
print(f"   Train: {X_train_base_seq.shape} → {y_train_seq.shape}")
print(f"   Val:   {X_val_base_seq.shape} → {y_val_seq.shape}")
print(f"   Test:  {X_test_base_seq.shape} → {y_test_seq.shape}")

print("\n📊 MODELO CON SENTIMIENTO:")
print(f"   Train: {X_train_sent_seq.shape} → {y_train_seq.shape}")
print(f"   Val:   {X_val_sent_seq.shape} → {y_val_seq.shape}")
print(f"   Test:  {X_test_sent_seq.shape} → {y_test_seq.shape}")

print(f"\n💡 Formato: (samples, seq_length, features)")
print(f"   - samples: número de secuencias")
print(f"   - seq_length: {SEQ_LENGTH} días de historia")
print(f"   - features: {len(features_base)} (base) / {len(features_sentiment)} (sentiment)")
# Out:
# 🔧 Creando secuencias (lookback=60 días)...
# ✅ Secuencias creadas
#
# 📊 MODELO BASE (sin sentimiento):
#    Train: (1282, 60, 6) → (1282, 1)
#    Val:   (387, 60, 6) → (387, 1)
#    Test:  (389, 60, 6) → (389, 1)
#
# 📊 MODELO CON SENTIMIENTO:
#    Train: (1282, 60, 9) → (1282, 1)
#    Val:   (387, 60, 9) → (387, 1)
#    Test:  (389, 60, 9) → (389, 1)
#
# 💡 Formato: (samples, seq_length, features)
#    - samples: número de secuencias
#    - seq_length: 60 días de historia
#    - features: 6 (base) / 9 (sentiment)

# %% [markdown]
# ---
#
# ## 8️⃣ Construcción del Modelo LSTM Base (sin sentimiento)

# %%
def build_lstm_model(input_shape, model_name="LSTM"):
    """
    Construye modelo LSTM con arquitectura 256-128-64.
    
    Args:
        input_shape: Tupla (seq_length, n_features)
        model_name: Nombre del modelo
    
    Returns:
        Modelo compilado
    """
    model = Sequential(name=model_name)
    
    # Capa de entrada
    model.add(Input(shape=input_shape))
    
    # Primera capa LSTM
    model.add(LSTM(256, return_sequences=True, name='lstm_1'))
    model.add(Dropout(0.2, name='dropout_1'))
    
    # Segunda capa LSTM
    model.add(LSTM(128, return_sequences=True, name='lstm_2'))
    model.add(Dropout(0.2, name='dropout_2'))
    
    # Tercera capa LSTM
    model.add(LSTM(64, return_sequences=False, name='lstm_3'))
    model.add(Dropout(0.2, name='dropout_3'))
    
    # Capa de salida
    model.add(Dense(1, name='output'))
    
    # Compilar modelo
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='mean_squared_error',
        metrics=['mae']
    )
    
    return model

# Construir modelo base
print("🔧 Construyendo Modelo LSTM Base (sin sentimiento)...\n")

model_base = build_lstm_model(
    input_shape=(SEQ_LENGTH, len(features_base)),
    model_name="LSTM_Base"
)

print("✅ Modelo Base construido")
print("\n" + "="*80)
model_base.summary()
print("="*80)
# Out:
# 🔧 Construyendo Modelo LSTM Base (sin sentimiento)...
#
# ✅ Modelo Base construido
#
# ================================================================================
# ✅ Modelo Base construido
#
# ================================================================================
# Model: "LSTM_Base"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 60, 256)        │       269,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 60, 128)        │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 515,905 (1.97 MB)
#  Trainable params: 515,905 (1.97 MB)
#  Non-trainable params: 0 (0.00 B)
# ================================================================================

# %% [markdown]
# ---
#
# ## 9️⃣ Entrenamiento del Modelo Base

# %%
# Configurar callbacks
callbacks_base = [
    EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=str(MODELOS_DIR / 'lstm_base_best.keras'),
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
]

print("🚀 Entrenando Modelo Base...\n")
print("Configuración:")
print(f"  - Epochs: 100 (con EarlyStopping)")
print(f"  - Batch size: 32")
print(f"  - Learning rate: 0.001 (con ReduceLROnPlateau)")
print(f"  - Patience: 15 epochs\n")
print("="*80)

# Entrenar modelo
history_base = model_base.fit(
    X_train_base_seq,
    y_train_seq,
    validation_data=(X_val_base_seq, y_val_seq),
    epochs=100,
    batch_size=32,
    callbacks=callbacks_base,
    verbose=1
)

print("\n" + "="*80)
print("✅ Entrenamiento completado")
# Out:
# 🚀 Entrenando Modelo Base...
#
# Configuración:
#   - Epochs: 100 (con EarlyStopping)
#   - Batch size: 32
#   - Learning rate: 0.001 (con ReduceLROnPlateau)
#   - Patience: 15 epochs
#
# ================================================================================
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0254 - mae: 0.0989
# Epoch 1: val_loss improved from None to 0.00601, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 1: val_loss improved from None to 0.00601, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - loss: 0.0102 - mae: 0.0625 - val_loss: 0.0060 - val_mae: 0.0586 - learning_rate: 0.0010
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - loss: 0.0102 - mae: 0.0625 - val_loss: 0.0060 - val_mae: 0.0586 - learning_rate: 0.0010
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0029 - mae: 0.0390
# Epoch 2: val_loss did not improve from 0.00601
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0035 - mae: 0.0412 - val_loss: 0.0071 - val_mae: 0.0635 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 2: val_loss did not improve from 0.00601
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0035 - mae: 0.0412 - val_loss: 0.0071 - val_mae: 0.0635 - learning_rate: 0.0010
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0037 - mae: 0.0447
# Epoch 3: val_loss improved from 0.00601 to 0.00538, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 3: val_loss improved from 0.00601 to 0.00538, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0038 - mae: 0.0448 - val_loss: 0.0054 - val_mae: 0.0553 - learning_rate: 0.0010
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0038 - mae: 0.0448 - val_loss: 0.0054 - val_mae: 0.0553 - learning_rate: 0.0010
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0031 - mae: 0.0414
# Epoch 4: val_loss improved from 0.00538 to 0.00464, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 4: val_loss improved from 0.00538 to 0.00464, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0030 - mae: 0.0397 - val_loss: 0.0046 - val_mae: 0.0522 - learning_rate: 0.0010
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0030 - mae: 0.0397 - val_loss: 0.0046 - val_mae: 0.0522 - learning_rate: 0.0010
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0027 - mae: 0.0384
# Epoch 5: val_loss did not improve from 0.00464
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0033 - mae: 0.0409 - val_loss: 0.0055 - val_mae: 0.0628 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 5: val_loss did not improve from 0.00464
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0033 - mae: 0.0409 - val_loss: 0.0055 - val_mae: 0.0628 - learning_rate: 0.0010
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0029 - mae: 0.0404
# Epoch 6: val_loss improved from 0.00464 to 0.00397, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 6: val_loss improved from 0.00464 to 0.00397, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0030 - mae: 0.0397 - val_loss: 0.0040 - val_mae: 0.0508 - learning_rate: 0.0010
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0030 - mae: 0.0397 - val_loss: 0.0040 - val_mae: 0.0508 - learning_rate: 0.0010
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0027 - mae: 0.0369
# Epoch 7: val_loss did not improve from 0.00397
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0030 - mae: 0.0380 - val_loss: 0.0061 - val_mae: 0.0675 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 7: val_loss did not improve from 0.00397
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0030 - mae: 0.0380 - val_loss: 0.0061 - val_mae: 0.0675 - learning_rate: 0.0010
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0036 - mae: 0.0436
# Epoch 8: val_loss did not improve from 0.00397
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0038 - mae: 0.0437 - val_loss: 0.0063 - val_mae: 0.0695 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 8: val_loss did not improve from 0.00397
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0038 - mae: 0.0437 - val_loss: 0.0063 - val_mae: 0.0695 - learning_rate: 0.0010
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0033 - mae: 0.0413
# Epoch 9: val_loss improved from 0.00397 to 0.00384, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 9: val_loss improved from 0.00397 to 0.00384, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0029 - mae: 0.0373 - val_loss: 0.0038 - val_mae: 0.0489 - learning_rate: 0.0010
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0029 - mae: 0.0373 - val_loss: 0.0038 - val_mae: 0.0489 - learning_rate: 0.0010
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0023 - mae: 0.0348
# Epoch 10: val_loss improved from 0.00384 to 0.00312, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 10: val_loss improved from 0.00384 to 0.00312, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 0.0023 - mae: 0.0344 - val_loss: 0.0031 - val_mae: 0.0427 - learning_rate: 0.0010
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 0.0023 - mae: 0.0344 - val_loss: 0.0031 - val_mae: 0.0427 - learning_rate: 0.0010
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0021 - mae: 0.0323
# Epoch 11: val_loss did not improve from 0.00312
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 0.0025 - mae: 0.0344 - val_loss: 0.0054 - val_mae: 0.0646 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 11: val_loss did not improve from 0.00312
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 0.0025 - mae: 0.0344 - val_loss: 0.0054 - val_mae: 0.0646 - learning_rate: 0.0010
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0026 - mae: 0.0360
# Epoch 12: val_loss did not improve from 0.00312
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0025 - mae: 0.0345 - val_loss: 0.0033 - val_mae: 0.0467 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 12: val_loss did not improve from 0.00312
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0025 - mae: 0.0345 - val_loss: 0.0033 - val_mae: 0.0467 - learning_rate: 0.0010
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0020 - mae: 0.0328
# Epoch 13: val_loss did not improve from 0.00312
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0021 - mae: 0.0327 - val_loss: 0.0047 - val_mae: 0.0509 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 13: val_loss did not improve from 0.00312
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0021 - mae: 0.0327 - val_loss: 0.0047 - val_mae: 0.0509 - learning_rate: 0.0010
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0019 - mae: 0.0315
# Epoch 14: val_loss improved from 0.00312 to 0.00281, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 14: val_loss improved from 0.00312 to 0.00281, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0020 - mae: 0.0318 - val_loss: 0.0028 - val_mae: 0.0426 - learning_rate: 0.0010
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0020 - mae: 0.0318 - val_loss: 0.0028 - val_mae: 0.0426 - learning_rate: 0.0010
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0022 - mae: 0.0329
# Epoch 15: val_loss did not improve from 0.00281
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 0.0023 - mae: 0.0330 - val_loss: 0.0038 - val_mae: 0.0531 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 15: val_loss did not improve from 0.00281
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 0.0023 - mae: 0.0330 - val_loss: 0.0038 - val_mae: 0.0531 - learning_rate: 0.0010
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0023 - mae: 0.0339
# Epoch 16: val_loss did not improve from 0.00281
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0024 - mae: 0.0336 - val_loss: 0.0055 - val_mae: 0.0658 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 16: val_loss did not improve from 0.00281
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0024 - mae: 0.0336 - val_loss: 0.0055 - val_mae: 0.0658 - learning_rate: 0.0010
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0024 - mae: 0.0355
# Epoch 17: val_loss improved from 0.00281 to 0.00254, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 17: val_loss improved from 0.00281 to 0.00254, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0023 - mae: 0.0336 - val_loss: 0.0025 - val_mae: 0.0374 - learning_rate: 0.0010
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0023 - mae: 0.0336 - val_loss: 0.0025 - val_mae: 0.0374 - learning_rate: 0.0010
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0019 - mae: 0.0308
# Epoch 18: val_loss did not improve from 0.00254
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0025 - mae: 0.0337 - val_loss: 0.0065 - val_mae: 0.0728 - learning_rate: 0.0010
# Epoch 19/100
#
# Epoch 18: val_loss did not improve from 0.00254
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0025 - mae: 0.0337 - val_loss: 0.0065 - val_mae: 0.0728 - learning_rate: 0.0010
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0023 - mae: 0.0343
# Epoch 19: val_loss did not improve from 0.00254
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 0.0021 - mae: 0.0315 - val_loss: 0.0028 - val_mae: 0.0399 - learning_rate: 0.0010
# Epoch 20/100
#
# Epoch 19: val_loss did not improve from 0.00254
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 0.0021 - mae: 0.0315 - val_loss: 0.0028 - val_mae: 0.0399 - learning_rate: 0.0010
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0015 - mae: 0.0282
# Epoch 20: val_loss improved from 0.00254 to 0.00229, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 20: val_loss improved from 0.00254 to 0.00229, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0016 - mae: 0.0280 - val_loss: 0.0023 - val_mae: 0.0370 - learning_rate: 0.0010
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0016 - mae: 0.0280 - val_loss: 0.0023 - val_mae: 0.0370 - learning_rate: 0.0010
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0017 - mae: 0.0282
# Epoch 21: val_loss improved from 0.00229 to 0.00218, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 21: val_loss improved from 0.00229 to 0.00218, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0017 - mae: 0.0283 - val_loss: 0.0022 - val_mae: 0.0357 - learning_rate: 0.0010
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0017 - mae: 0.0283 - val_loss: 0.0022 - val_mae: 0.0357 - learning_rate: 0.0010
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0014 - mae: 0.0265
# Epoch 22: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0016 - mae: 0.0271 - val_loss: 0.0027 - val_mae: 0.0367 - learning_rate: 0.0010
# Epoch 23/100
#
# Epoch 22: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0016 - mae: 0.0271 - val_loss: 0.0027 - val_mae: 0.0367 - learning_rate: 0.0010
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0015 - mae: 0.0264
# Epoch 23: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0018 - mae: 0.0287 - val_loss: 0.0044 - val_mae: 0.0585 - learning_rate: 0.0010
# Epoch 24/100
#
# Epoch 23: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0018 - mae: 0.0287 - val_loss: 0.0044 - val_mae: 0.0585 - learning_rate: 0.0010
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0020 - mae: 0.0304
# Epoch 24: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0018 - mae: 0.0285 - val_loss: 0.0036 - val_mae: 0.0524 - learning_rate: 0.0010
# Epoch 25/100
#
# Epoch 24: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0018 - mae: 0.0285 - val_loss: 0.0036 - val_mae: 0.0524 - learning_rate: 0.0010
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0019 - mae: 0.0295
# Epoch 25: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 0.0018 - mae: 0.0283 - val_loss: 0.0026 - val_mae: 0.0414 - learning_rate: 0.0010
# Epoch 26/100
#
# Epoch 25: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 0.0018 - mae: 0.0283 - val_loss: 0.0026 - val_mae: 0.0414 - learning_rate: 0.0010
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0016 - mae: 0.0279
# Epoch 26: val_loss did not improve from 0.00218
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0016 - mae: 0.0276 - val_loss: 0.0029 - val_mae: 0.0379 - learning_rate: 0.0010
# Epoch 27/100
#
# Epoch 26: val_loss did not improve from 0.00218
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0016 - mae: 0.0276 - val_loss: 0.0029 - val_mae: 0.0379 - learning_rate: 0.0010
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0014 - mae: 0.0242
# Epoch 27: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0015 - mae: 0.0249 - val_loss: 0.0023 - val_mae: 0.0361 - learning_rate: 5.0000e-04
# Epoch 28/100
#
# Epoch 27: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0015 - mae: 0.0249 - val_loss: 0.0023 - val_mae: 0.0361 - learning_rate: 5.0000e-04
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0015 - mae: 0.0261
# Epoch 28: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0016 - mae: 0.0271 - val_loss: 0.0028 - val_mae: 0.0367 - learning_rate: 5.0000e-04
# Epoch 29/100
#
# Epoch 28: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0016 - mae: 0.0271 - val_loss: 0.0028 - val_mae: 0.0367 - learning_rate: 5.0000e-04
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0015 - mae: 0.0261
# Epoch 29: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0015 - mae: 0.0258 - val_loss: 0.0048 - val_mae: 0.0522 - learning_rate: 5.0000e-04
# Epoch 30/100
#
# Epoch 29: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0015 - mae: 0.0258 - val_loss: 0.0048 - val_mae: 0.0522 - learning_rate: 5.0000e-04
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0015 - mae: 0.0254
# Epoch 30: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0015 - mae: 0.0248 - val_loss: 0.0024 - val_mae: 0.0339 - learning_rate: 5.0000e-04
# Epoch 31/100
#
# Epoch 30: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0015 - mae: 0.0248 - val_loss: 0.0024 - val_mae: 0.0339 - learning_rate: 5.0000e-04
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0016 - mae: 0.0259
# Epoch 31: val_loss did not improve from 0.00218
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0016 - mae: 0.0266 - val_loss: 0.0023 - val_mae: 0.0337 - learning_rate: 5.0000e-04
# Epoch 32/100
#
# Epoch 31: val_loss did not improve from 0.00218
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0016 - mae: 0.0266 - val_loss: 0.0023 - val_mae: 0.0337 - learning_rate: 5.0000e-04
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0014 - mae: 0.0243
# Epoch 32: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0014 - mae: 0.0251 - val_loss: 0.0023 - val_mae: 0.0331 - learning_rate: 2.5000e-04
# Epoch 33/100
#
# Epoch 32: val_loss did not improve from 0.00218
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0014 - mae: 0.0251 - val_loss: 0.0023 - val_mae: 0.0331 - learning_rate: 2.5000e-04
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0013 - mae: 0.0237
# Epoch 33: val_loss improved from 0.00218 to 0.00196, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 33: val_loss improved from 0.00218 to 0.00196, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0013 - mae: 0.0242 - val_loss: 0.0020 - val_mae: 0.0319 - learning_rate: 2.5000e-04
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0013 - mae: 0.0242 - val_loss: 0.0020 - val_mae: 0.0319 - learning_rate: 2.5000e-04
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0011 - mae: 0.0229
# Epoch 34: val_loss improved from 0.00196 to 0.00189, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 34: val_loss improved from 0.00196 to 0.00189, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0240 - val_loss: 0.0019 - val_mae: 0.0330 - learning_rate: 2.5000e-04
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0240 - val_loss: 0.0019 - val_mae: 0.0330 - learning_rate: 2.5000e-04
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0013 - mae: 0.0249
# Epoch 35: val_loss did not improve from 0.00189
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0013 - mae: 0.0248 - val_loss: 0.0024 - val_mae: 0.0342 - learning_rate: 2.5000e-04
# Epoch 36/100
#
# Epoch 35: val_loss did not improve from 0.00189
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0013 - mae: 0.0248 - val_loss: 0.0024 - val_mae: 0.0342 - learning_rate: 2.5000e-04
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0013 - mae: 0.0237
# Epoch 36: val_loss did not improve from 0.00189
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0013 - mae: 0.0238 - val_loss: 0.0023 - val_mae: 0.0328 - learning_rate: 2.5000e-04
# Epoch 37/100
#
# Epoch 36: val_loss did not improve from 0.00189
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0013 - mae: 0.0238 - val_loss: 0.0023 - val_mae: 0.0328 - learning_rate: 2.5000e-04
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0011 - mae: 0.0226
# Epoch 37: val_loss did not improve from 0.00189
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0013 - mae: 0.0238 - val_loss: 0.0021 - val_mae: 0.0319 - learning_rate: 2.5000e-04
# Epoch 38/100
#
# Epoch 37: val_loss did not improve from 0.00189
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0013 - mae: 0.0238 - val_loss: 0.0021 - val_mae: 0.0319 - learning_rate: 2.5000e-04
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0012 - mae: 0.0228
# Epoch 38: val_loss did not improve from 0.00189
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0014 - mae: 0.0252 - val_loss: 0.0026 - val_mae: 0.0360 - learning_rate: 2.5000e-04
# Epoch 39/100
#
# Epoch 38: val_loss did not improve from 0.00189
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0014 - mae: 0.0252 - val_loss: 0.0026 - val_mae: 0.0360 - learning_rate: 2.5000e-04
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0010 - mae: 0.0217
# Epoch 39: val_loss did not improve from 0.00189
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0011 - mae: 0.0222 - val_loss: 0.0025 - val_mae: 0.0351 - learning_rate: 1.2500e-04
# Epoch 40/100
#
# Epoch 39: val_loss did not improve from 0.00189
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0011 - mae: 0.0222 - val_loss: 0.0025 - val_mae: 0.0351 - learning_rate: 1.2500e-04
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0012 - mae: 0.0234
# Epoch 40: val_loss improved from 0.00189 to 0.00187, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 40: val_loss improved from 0.00189 to 0.00187, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0013 - mae: 0.0237 - val_loss: 0.0019 - val_mae: 0.0301 - learning_rate: 1.2500e-04
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0013 - mae: 0.0237 - val_loss: 0.0019 - val_mae: 0.0301 - learning_rate: 1.2500e-04
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0011 - mae: 0.0226
# Epoch 41: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0234 - val_loss: 0.0024 - val_mae: 0.0340 - learning_rate: 1.2500e-04
# Epoch 42/100
#
# Epoch 41: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0234 - val_loss: 0.0024 - val_mae: 0.0340 - learning_rate: 1.2500e-04
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 9.7804e-04 - mae: 0.0212
# Epoch 42: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0011 - mae: 0.0229 - val_loss: 0.0020 - val_mae: 0.0307 - learning_rate: 1.2500e-04
# Epoch 43/100
#
# Epoch 42: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0011 - mae: 0.0229 - val_loss: 0.0020 - val_mae: 0.0307 - learning_rate: 1.2500e-04
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0011 - mae: 0.0213
# Epoch 43: val_loss did not improve from 0.00187
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0224 - val_loss: 0.0022 - val_mae: 0.0324 - learning_rate: 1.2500e-04
# Epoch 44/100
#
# Epoch 43: val_loss did not improve from 0.00187
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0224 - val_loss: 0.0022 - val_mae: 0.0324 - learning_rate: 1.2500e-04
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 9.8262e-04 - mae: 0.0214
# Epoch 44: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0011 - mae: 0.0224 - val_loss: 0.0023 - val_mae: 0.0327 - learning_rate: 6.2500e-05
# Epoch 45/100
#
# Epoch 44: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0011 - mae: 0.0224 - val_loss: 0.0023 - val_mae: 0.0327 - learning_rate: 6.2500e-05
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 9.9974e-04 - mae: 0.0215
# Epoch 45: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0012 - mae: 0.0227 - val_loss: 0.0021 - val_mae: 0.0317 - learning_rate: 6.2500e-05
# Epoch 46/100
#
# Epoch 45: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0012 - mae: 0.0227 - val_loss: 0.0021 - val_mae: 0.0317 - learning_rate: 6.2500e-05
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0011 - mae: 0.0223
# Epoch 46: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0012 - mae: 0.0226 - val_loss: 0.0027 - val_mae: 0.0366 - learning_rate: 6.2500e-05
# Epoch 47/100
#
# Epoch 46: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0012 - mae: 0.0226 - val_loss: 0.0027 - val_mae: 0.0366 - learning_rate: 6.2500e-05
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0013 - mae: 0.0232
# Epoch 47: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0013 - mae: 0.0238 - val_loss: 0.0025 - val_mae: 0.0354 - learning_rate: 6.2500e-05
# Epoch 48/100
#
# Epoch 47: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0013 - mae: 0.0238 - val_loss: 0.0025 - val_mae: 0.0354 - learning_rate: 6.2500e-05
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0011 - mae: 0.0215
# Epoch 48: val_loss did not improve from 0.00187
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0011 - mae: 0.0216 - val_loss: 0.0020 - val_mae: 0.0310 - learning_rate: 6.2500e-05
# Epoch 49/100
#
# Epoch 48: val_loss did not improve from 0.00187
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0011 - mae: 0.0216 - val_loss: 0.0020 - val_mae: 0.0310 - learning_rate: 6.2500e-05
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0011 - mae: 0.0220
# Epoch 49: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0012 - mae: 0.0224 - val_loss: 0.0020 - val_mae: 0.0310 - learning_rate: 3.1250e-05
# Epoch 50/100
#
# Epoch 49: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0012 - mae: 0.0224 - val_loss: 0.0020 - val_mae: 0.0310 - learning_rate: 3.1250e-05
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0011 - mae: 0.0211
# Epoch 50: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0222 - val_loss: 0.0021 - val_mae: 0.0312 - learning_rate: 3.1250e-05
# Epoch 51/100
#
# Epoch 50: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0222 - val_loss: 0.0021 - val_mae: 0.0312 - learning_rate: 3.1250e-05
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 9.9143e-04 - mae: 0.0209
# Epoch 51: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0011 - mae: 0.0221 - val_loss: 0.0023 - val_mae: 0.0327 - learning_rate: 3.1250e-05
# Epoch 52/100
#
# Epoch 51: val_loss did not improve from 0.00187
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0011 - mae: 0.0221 - val_loss: 0.0023 - val_mae: 0.0327 - learning_rate: 3.1250e-05
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0012 - mae: 0.0222
# Epoch 52: val_loss improved from 0.00187 to 0.00186, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
#
# Epoch 52: val_loss improved from 0.00187 to 0.00186, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_base_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0012 - mae: 0.0227 - val_loss: 0.0019 - val_mae: 0.0300 - learning_rate: 3.1250e-05
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0012 - mae: 0.0227 - val_loss: 0.0019 - val_mae: 0.0300 - learning_rate: 3.1250e-05
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0011 - mae: 0.0216
# Epoch 53: val_loss did not improve from 0.00186
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0011 - mae: 0.0216 - val_loss: 0.0025 - val_mae: 0.0349 - learning_rate: 3.1250e-05
# Epoch 54/100
#
# Epoch 53: val_loss did not improve from 0.00186
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0011 - mae: 0.0216 - val_loss: 0.0025 - val_mae: 0.0349 - learning_rate: 3.1250e-05
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0012 - mae: 0.0220
# Epoch 54: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 0.0013 - mae: 0.0229 - val_loss: 0.0021 - val_mae: 0.0314 - learning_rate: 1.5625e-05
# Epoch 55/100
#
# Epoch 54: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 0.0013 - mae: 0.0229 - val_loss: 0.0021 - val_mae: 0.0314 - learning_rate: 1.5625e-05
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0011 - mae: 0.0216
# Epoch 55: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0013 - mae: 0.0229 - val_loss: 0.0027 - val_mae: 0.0367 - learning_rate: 1.5625e-05
# Epoch 56/100
#
# Epoch 55: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0013 - mae: 0.0229 - val_loss: 0.0027 - val_mae: 0.0367 - learning_rate: 1.5625e-05
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0012 - mae: 0.0226
# Epoch 56: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0013 - mae: 0.0231 - val_loss: 0.0023 - val_mae: 0.0331 - learning_rate: 1.5625e-05
# Epoch 57/100
#
# Epoch 56: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0013 - mae: 0.0231 - val_loss: 0.0023 - val_mae: 0.0331 - learning_rate: 1.5625e-05
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0011 - mae: 0.0214
# Epoch 57: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0224 - val_loss: 0.0022 - val_mae: 0.0320 - learning_rate: 1.5625e-05
# Epoch 58/100
#
# Epoch 57: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0224 - val_loss: 0.0022 - val_mae: 0.0320 - learning_rate: 1.5625e-05
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0011 - mae: 0.0214
# Epoch 58: val_loss did not improve from 0.00186
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0011 - mae: 0.0219 - val_loss: 0.0020 - val_mae: 0.0308 - learning_rate: 1.5625e-05
# Epoch 59/100
#
# Epoch 58: val_loss did not improve from 0.00186
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0011 - mae: 0.0219 - val_loss: 0.0020 - val_mae: 0.0308 - learning_rate: 1.5625e-05
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0012 - mae: 0.0220
# Epoch 59: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0232 - val_loss: 0.0021 - val_mae: 0.0313 - learning_rate: 7.8125e-06
# Epoch 60/100
#
# Epoch 59: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0232 - val_loss: 0.0021 - val_mae: 0.0313 - learning_rate: 7.8125e-06
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0010 - mae: 0.0208
# Epoch 60: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0011 - mae: 0.0217 - val_loss: 0.0023 - val_mae: 0.0335 - learning_rate: 7.8125e-06
# Epoch 61/100
#
# Epoch 60: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0011 - mae: 0.0217 - val_loss: 0.0023 - val_mae: 0.0335 - learning_rate: 7.8125e-06
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0011 - mae: 0.0220
# Epoch 61: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0229 - val_loss: 0.0024 - val_mae: 0.0338 - learning_rate: 7.8125e-06
# Epoch 62/100
#
# Epoch 61: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0229 - val_loss: 0.0024 - val_mae: 0.0338 - learning_rate: 7.8125e-06
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 9.7923e-04 - mae: 0.0207
# Epoch 62: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0011 - mae: 0.0219 - val_loss: 0.0024 - val_mae: 0.0338 - learning_rate: 7.8125e-06
# Epoch 63/100
#
# Epoch 62: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0011 - mae: 0.0219 - val_loss: 0.0024 - val_mae: 0.0338 - learning_rate: 7.8125e-06
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0010 - mae: 0.0215
# Epoch 63: val_loss did not improve from 0.00186
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0011 - mae: 0.0219 - val_loss: 0.0022 - val_mae: 0.0320 - learning_rate: 7.8125e-06
# Epoch 64/100
#
# Epoch 63: val_loss did not improve from 0.00186
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0011 - mae: 0.0219 - val_loss: 0.0022 - val_mae: 0.0320 - learning_rate: 7.8125e-06
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 9.7441e-04 - mae: 0.0208
# Epoch 64: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0010 - mae: 0.0217 - val_loss: 0.0022 - val_mae: 0.0320 - learning_rate: 3.9063e-06
# Epoch 65/100
#
# Epoch 64: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0010 - mae: 0.0217 - val_loss: 0.0022 - val_mae: 0.0320 - learning_rate: 3.9063e-06
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0011 - mae: 0.0220
# Epoch 65: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 0.0022 - val_mae: 0.0319 - learning_rate: 3.9063e-06
# Epoch 66/100
#
# Epoch 65: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 0.0022 - val_mae: 0.0319 - learning_rate: 3.9063e-06
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0011 - mae: 0.0218
# Epoch 66: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 0.0023 - val_mae: 0.0333 - learning_rate: 3.9063e-06
# Epoch 67/100
#
# Epoch 66: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 0.0023 - val_mae: 0.0333 - learning_rate: 3.9063e-06
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0011 - mae: 0.0218
# Epoch 67: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0012 - mae: 0.0227 - val_loss: 0.0023 - val_mae: 0.0328 - learning_rate: 3.9063e-06
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 52.
#
# Epoch 67: val_loss did not improve from 0.00186
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0012 - mae: 0.0227 - val_loss: 0.0023 - val_mae: 0.0328 - learning_rate: 3.9063e-06
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 52.
#
# ================================================================================
# ✅ Entrenamiento completado
#
# ================================================================================
# ✅ Entrenamiento completado

# %%
# Visualizar curvas de aprendizaje
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=('Loss (MSE)', 'MAE')
)

# Loss
fig.add_trace(
    go.Scatter(y=history_base.history['loss'], mode='lines', name='Train Loss'),
    row=1, col=1
)
fig.add_trace(
    go.Scatter(y=history_base.history['val_loss'], mode='lines', name='Val Loss'),
    row=1, col=1
)

# MAE
fig.add_trace(
    go.Scatter(y=history_base.history['mae'], mode='lines', name='Train MAE'),
    row=1, col=2
)
fig.add_trace(
    go.Scatter(y=history_base.history['val_mae'], mode='lines', name='Val MAE'),
    row=1, col=2
)

fig.update_xaxes(title_text="Epoch", row=1, col=1)
fig.update_xaxes(title_text="Epoch", row=1, col=2)
fig.update_yaxes(title_text="Loss", row=1, col=1)
fig.update_yaxes(title_text="MAE", row=1, col=2)

fig.update_layout(
    title_text="Curvas de Aprendizaje - Modelo Base",
    template='plotly_white',
    height=400
)

fig.show()

print(f"\n📊 Resultados finales:")
print(f"   Train Loss: {history_base.history['loss'][-1]:.6f}")
print(f"   Val Loss: {history_base.history['val_loss'][-1]:.6f}")
print(f"   Train MAE: {history_base.history['mae'][-1]:.6f}")
print(f"   Val MAE: {history_base.history['val_mae'][-1]:.6f}")
# Out:
# 📊 Resultados finales:
#    Train Loss: 0.001241
#    Val Loss: 0.002267
#    Train MAE: 0.022700
#    Val MAE: 0.032848

# %% [markdown]
# ---
#
# ## 🔟 Construcción y Entrenamiento del Modelo con Sentimiento

# %%
# Construir modelo con sentimiento
print("🔧 Construyendo Modelo LSTM con Sentimiento...\n")

model_sentiment = build_lstm_model(
    input_shape=(SEQ_LENGTH, len(features_sentiment)),
    model_name="LSTM_Sentiment"
)

print("✅ Modelo con Sentimiento construido")
print("\n" + "="*80)
model_sentiment.summary()
print("="*80)
# Out:
# 🔧 Construyendo Modelo LSTM con Sentimiento...
#
# ✅ Modelo con Sentimiento construido
#
# ================================================================================
# ✅ Modelo con Sentimiento construido
#
# ================================================================================
# Model: "LSTM_Sentiment"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 60, 256)        │       272,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 60, 128)        │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 518,977 (1.98 MB)
#  Trainable params: 518,977 (1.98 MB)
#  Non-trainable params: 0 (0.00 B)
# ================================================================================

# %%
# Configurar callbacks
callbacks_sentiment = [
    EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=str(MODELOS_DIR / 'lstm_sentiment_best.keras'),
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
]

print("🚀 Entrenando Modelo con Sentimiento...\n")
print("="*80)

# Entrenar modelo
history_sentiment = model_sentiment.fit(
    X_train_sent_seq,
    y_train_seq,
    validation_data=(X_val_sent_seq, y_val_seq),
    epochs=100,
    batch_size=32,
    callbacks=callbacks_sentiment,
    verbose=1
)

print("\n" + "="*80)
print("✅ Entrenamiento completado")
# Out:
# 🚀 Entrenando Modelo con Sentimiento...
#
# ================================================================================
# Epoch 1/100
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0364 - mae: 0.1243
# Epoch 1: val_loss improved from None to 0.00816, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 1: val_loss improved from None to 0.00816, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 106ms/step - loss: 0.0143 - mae: 0.0760 - val_loss: 0.0082 - val_mae: 0.0655 - learning_rate: 0.0010
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 106ms/step - loss: 0.0143 - mae: 0.0760 - val_loss: 0.0082 - val_mae: 0.0655 - learning_rate: 0.0010
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0031 - mae: 0.0399
# Epoch 2: val_loss improved from 0.00816 to 0.00531, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 2: val_loss improved from 0.00816 to 0.00531, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0031 - mae: 0.0403 - val_loss: 0.0053 - val_mae: 0.0555 - learning_rate: 0.0010
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0031 - mae: 0.0403 - val_loss: 0.0053 - val_mae: 0.0555 - learning_rate: 0.0010
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0030 - mae: 0.0403
# Epoch 3: val_loss improved from 0.00531 to 0.00515, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 3: val_loss improved from 0.00531 to 0.00515, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0031 - mae: 0.0407 - val_loss: 0.0052 - val_mae: 0.0535 - learning_rate: 0.0010
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0031 - mae: 0.0407 - val_loss: 0.0052 - val_mae: 0.0535 - learning_rate: 0.0010
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0033 - mae: 0.0417
# Epoch 4: val_loss did not improve from 0.00515
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0042 - mae: 0.0473 - val_loss: 0.0168 - val_mae: 0.1062 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 4: val_loss did not improve from 0.00515
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0042 - mae: 0.0473 - val_loss: 0.0168 - val_mae: 0.1062 - learning_rate: 0.0010
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0040 - mae: 0.0462
# Epoch 5: val_loss did not improve from 0.00515
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 0.0034 - mae: 0.0419 - val_loss: 0.0069 - val_mae: 0.0608 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 5: val_loss did not improve from 0.00515
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 0.0034 - mae: 0.0419 - val_loss: 0.0069 - val_mae: 0.0608 - learning_rate: 0.0010
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0027 - mae: 0.0374
# Epoch 6: val_loss did not improve from 0.00515
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0029 - mae: 0.0387 - val_loss: 0.0054 - val_mae: 0.0612 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 6: val_loss did not improve from 0.00515
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0029 - mae: 0.0387 - val_loss: 0.0054 - val_mae: 0.0612 - learning_rate: 0.0010
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0030 - mae: 0.0410
# Epoch 7: val_loss did not improve from 0.00515
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0030 - mae: 0.0400 - val_loss: 0.0064 - val_mae: 0.0693 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 7: val_loss did not improve from 0.00515
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0030 - mae: 0.0400 - val_loss: 0.0064 - val_mae: 0.0693 - learning_rate: 0.0010
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0033 - mae: 0.0420
# Epoch 8: val_loss improved from 0.00515 to 0.00404, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 8: val_loss improved from 0.00515 to 0.00404, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0031 - mae: 0.0404 - val_loss: 0.0040 - val_mae: 0.0484 - learning_rate: 0.0010
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0031 - mae: 0.0404 - val_loss: 0.0040 - val_mae: 0.0484 - learning_rate: 0.0010
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0027 - mae: 0.0386
# Epoch 9: val_loss did not improve from 0.00404
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0026 - mae: 0.0372 - val_loss: 0.0054 - val_mae: 0.0543 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 9: val_loss did not improve from 0.00404
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0026 - mae: 0.0372 - val_loss: 0.0054 - val_mae: 0.0543 - learning_rate: 0.0010
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0023 - mae: 0.0346
# Epoch 10: val_loss improved from 0.00404 to 0.00357, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 10: val_loss improved from 0.00404 to 0.00357, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0024 - mae: 0.0351 - val_loss: 0.0036 - val_mae: 0.0441 - learning_rate: 0.0010
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0024 - mae: 0.0351 - val_loss: 0.0036 - val_mae: 0.0441 - learning_rate: 0.0010
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0024 - mae: 0.0364
# Epoch 11: val_loss did not improve from 0.00357
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0024 - mae: 0.0354 - val_loss: 0.0038 - val_mae: 0.0510 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 11: val_loss did not improve from 0.00357
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0024 - mae: 0.0354 - val_loss: 0.0038 - val_mae: 0.0510 - learning_rate: 0.0010
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0025 - mae: 0.0369
# Epoch 12: val_loss improved from 0.00357 to 0.00321, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 12: val_loss improved from 0.00357 to 0.00321, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0027 - mae: 0.0372 - val_loss: 0.0032 - val_mae: 0.0417 - learning_rate: 0.0010
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0027 - mae: 0.0372 - val_loss: 0.0032 - val_mae: 0.0417 - learning_rate: 0.0010
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0023 - mae: 0.0353
# Epoch 13: val_loss did not improve from 0.00321
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0027 - mae: 0.0378 - val_loss: 0.0037 - val_mae: 0.0496 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 13: val_loss did not improve from 0.00321
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0027 - mae: 0.0378 - val_loss: 0.0037 - val_mae: 0.0496 - learning_rate: 0.0010
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0021 - mae: 0.0332
# Epoch 14: val_loss did not improve from 0.00321
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0023 - mae: 0.0341 - val_loss: 0.0032 - val_mae: 0.0436 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 14: val_loss did not improve from 0.00321
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0023 - mae: 0.0341 - val_loss: 0.0032 - val_mae: 0.0436 - learning_rate: 0.0010
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0021 - mae: 0.0328
# Epoch 15: val_loss improved from 0.00321 to 0.00317, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 15: val_loss improved from 0.00321 to 0.00317, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0021 - mae: 0.0327 - val_loss: 0.0032 - val_mae: 0.0447 - learning_rate: 0.0010
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0021 - mae: 0.0327 - val_loss: 0.0032 - val_mae: 0.0447 - learning_rate: 0.0010
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0019 - mae: 0.0314
# Epoch 16: val_loss did not improve from 0.00317
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0021 - mae: 0.0331 - val_loss: 0.0032 - val_mae: 0.0451 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 16: val_loss did not improve from 0.00317
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0021 - mae: 0.0331 - val_loss: 0.0032 - val_mae: 0.0451 - learning_rate: 0.0010
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0020 - mae: 0.0315
# Epoch 17: val_loss improved from 0.00317 to 0.00301, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 17: val_loss improved from 0.00317 to 0.00301, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 0.0020 - mae: 0.0315 - val_loss: 0.0030 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 0.0020 - mae: 0.0315 - val_loss: 0.0030 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0019 - mae: 0.0307
# Epoch 18: val_loss did not improve from 0.00301
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0025 - mae: 0.0350 - val_loss: 0.0050 - val_mae: 0.0619 - learning_rate: 0.0010
# Epoch 19/100
#
# Epoch 18: val_loss did not improve from 0.00301
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0025 - mae: 0.0350 - val_loss: 0.0050 - val_mae: 0.0619 - learning_rate: 0.0010
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0023 - mae: 0.0353
# Epoch 19: val_loss did not improve from 0.00301
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0023 - mae: 0.0342 - val_loss: 0.0034 - val_mae: 0.0470 - learning_rate: 0.0010
# Epoch 20/100
#
# Epoch 19: val_loss did not improve from 0.00301
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0023 - mae: 0.0342 - val_loss: 0.0034 - val_mae: 0.0470 - learning_rate: 0.0010
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0023 - mae: 0.0340
# Epoch 20: val_loss did not improve from 0.00301
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0024 - mae: 0.0342 - val_loss: 0.0031 - val_mae: 0.0399 - learning_rate: 0.0010
# Epoch 21/100
#
# Epoch 20: val_loss did not improve from 0.00301
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0024 - mae: 0.0342 - val_loss: 0.0031 - val_mae: 0.0399 - learning_rate: 0.0010
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0019 - mae: 0.0300
# Epoch 21: val_loss did not improve from 0.00301
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0020 - mae: 0.0313 - val_loss: 0.0033 - val_mae: 0.0445 - learning_rate: 0.0010
# Epoch 22/100
#
# Epoch 21: val_loss did not improve from 0.00301
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0020 - mae: 0.0313 - val_loss: 0.0033 - val_mae: 0.0445 - learning_rate: 0.0010
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0021 - mae: 0.0329
# Epoch 22: val_loss did not improve from 0.00301
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0021 - mae: 0.0327 - val_loss: 0.0033 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 23/100
#
# Epoch 22: val_loss did not improve from 0.00301
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0021 - mae: 0.0327 - val_loss: 0.0033 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0017 - mae: 0.0289
# Epoch 23: val_loss improved from 0.00301 to 0.00299, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 23: val_loss improved from 0.00301 to 0.00299, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0019 - mae: 0.0301 - val_loss: 0.0030 - val_mae: 0.0387 - learning_rate: 5.0000e-04
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0019 - mae: 0.0301 - val_loss: 0.0030 - val_mae: 0.0387 - learning_rate: 5.0000e-04
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0018 - mae: 0.0286
# Epoch 24: val_loss did not improve from 0.00299
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0017 - mae: 0.0288 - val_loss: 0.0036 - val_mae: 0.0424 - learning_rate: 5.0000e-04
# Epoch 25/100
#
# Epoch 24: val_loss did not improve from 0.00299
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0017 - mae: 0.0288 - val_loss: 0.0036 - val_mae: 0.0424 - learning_rate: 5.0000e-04
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0013 - mae: 0.0251
# Epoch 25: val_loss improved from 0.00299 to 0.00294, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 25: val_loss improved from 0.00299 to 0.00294, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0014 - mae: 0.0262 - val_loss: 0.0029 - val_mae: 0.0380 - learning_rate: 5.0000e-04
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0014 - mae: 0.0262 - val_loss: 0.0029 - val_mae: 0.0380 - learning_rate: 5.0000e-04
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0014 - mae: 0.0257
# Epoch 26: val_loss improved from 0.00294 to 0.00292, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 26: val_loss improved from 0.00294 to 0.00292, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0015 - mae: 0.0266 - val_loss: 0.0029 - val_mae: 0.0381 - learning_rate: 5.0000e-04
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0015 - mae: 0.0266 - val_loss: 0.0029 - val_mae: 0.0381 - learning_rate: 5.0000e-04
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0014 - mae: 0.0257
# Epoch 27: val_loss improved from 0.00292 to 0.00267, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 27: val_loss improved from 0.00292 to 0.00267, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 0.0014 - mae: 0.0258 - val_loss: 0.0027 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 0.0014 - mae: 0.0258 - val_loss: 0.0027 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0016 - mae: 0.0275
# Epoch 28: val_loss did not improve from 0.00267
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 0.0018 - mae: 0.0293 - val_loss: 0.0030 - val_mae: 0.0387 - learning_rate: 5.0000e-04
# Epoch 29/100
#
# Epoch 28: val_loss did not improve from 0.00267
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 0.0018 - mae: 0.0293 - val_loss: 0.0030 - val_mae: 0.0387 - learning_rate: 5.0000e-04
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0014 - mae: 0.0260
# Epoch 29: val_loss improved from 0.00267 to 0.00236, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 29: val_loss improved from 0.00267 to 0.00236, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0015 - mae: 0.0268 - val_loss: 0.0024 - val_mae: 0.0342 - learning_rate: 5.0000e-04
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0015 - mae: 0.0268 - val_loss: 0.0024 - val_mae: 0.0342 - learning_rate: 5.0000e-04
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0013 - mae: 0.0251
# Epoch 30: val_loss improved from 0.00236 to 0.00233, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 30: val_loss improved from 0.00236 to 0.00233, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0013 - mae: 0.0256 - val_loss: 0.0023 - val_mae: 0.0343 - learning_rate: 5.0000e-04
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0013 - mae: 0.0256 - val_loss: 0.0023 - val_mae: 0.0343 - learning_rate: 5.0000e-04
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0017 - mae: 0.0276
# Epoch 31: val_loss did not improve from 0.00233
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0017 - mae: 0.0283 - val_loss: 0.0026 - val_mae: 0.0364 - learning_rate: 5.0000e-04
# Epoch 32/100
#
# Epoch 31: val_loss did not improve from 0.00233
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0017 - mae: 0.0283 - val_loss: 0.0026 - val_mae: 0.0364 - learning_rate: 5.0000e-04
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0015 - mae: 0.0271
# Epoch 32: val_loss did not improve from 0.00233
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0016 - mae: 0.0272 - val_loss: 0.0024 - val_mae: 0.0353 - learning_rate: 5.0000e-04
# Epoch 33/100
#
# Epoch 32: val_loss did not improve from 0.00233
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0016 - mae: 0.0272 - val_loss: 0.0024 - val_mae: 0.0353 - learning_rate: 5.0000e-04
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0015 - mae: 0.0259
# Epoch 33: val_loss improved from 0.00233 to 0.00233, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 33: val_loss improved from 0.00233 to 0.00233, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0015 - mae: 0.0259 - val_loss: 0.0023 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0015 - mae: 0.0259 - val_loss: 0.0023 - val_mae: 0.0362 - learning_rate: 5.0000e-04
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0015 - mae: 0.0260
# Epoch 34: val_loss did not improve from 0.00233
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 0.0028 - val_mae: 0.0371 - learning_rate: 5.0000e-04
# Epoch 35/100
#
# Epoch 34: val_loss did not improve from 0.00233
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 0.0028 - val_mae: 0.0371 - learning_rate: 5.0000e-04
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0013 - mae: 0.0245
# Epoch 35: val_loss did not improve from 0.00233
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0014 - mae: 0.0255 - val_loss: 0.0036 - val_mae: 0.0424 - learning_rate: 2.5000e-04
# Epoch 36/100
#
# Epoch 35: val_loss did not improve from 0.00233
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0014 - mae: 0.0255 - val_loss: 0.0036 - val_mae: 0.0424 - learning_rate: 2.5000e-04
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0013 - mae: 0.0241
# Epoch 36: val_loss did not improve from 0.00233
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0240 - val_loss: 0.0026 - val_mae: 0.0356 - learning_rate: 2.5000e-04
# Epoch 37/100
#
# Epoch 36: val_loss did not improve from 0.00233
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0240 - val_loss: 0.0026 - val_mae: 0.0356 - learning_rate: 2.5000e-04
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0013 - mae: 0.0243
# Epoch 37: val_loss improved from 0.00233 to 0.00226, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 37: val_loss improved from 0.00233 to 0.00226, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0013 - mae: 0.0250 - val_loss: 0.0023 - val_mae: 0.0333 - learning_rate: 2.5000e-04
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0013 - mae: 0.0250 - val_loss: 0.0023 - val_mae: 0.0333 - learning_rate: 2.5000e-04
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0012 - mae: 0.0240
# Epoch 38: val_loss did not improve from 0.00226
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 0.0024 - val_mae: 0.0343 - learning_rate: 2.5000e-04
# Epoch 39/100
#
# Epoch 38: val_loss did not improve from 0.00226
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 0.0024 - val_mae: 0.0343 - learning_rate: 2.5000e-04
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0013 - mae: 0.0241
# Epoch 39: val_loss did not improve from 0.00226
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0013 - mae: 0.0247 - val_loss: 0.0030 - val_mae: 0.0384 - learning_rate: 2.5000e-04
# Epoch 40/100
#
# Epoch 39: val_loss did not improve from 0.00226
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0013 - mae: 0.0247 - val_loss: 0.0030 - val_mae: 0.0384 - learning_rate: 2.5000e-04
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0014 - mae: 0.0243
# Epoch 40: val_loss did not improve from 0.00226
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0014 - mae: 0.0247 - val_loss: 0.0025 - val_mae: 0.0351 - learning_rate: 1.2500e-04
# Epoch 41/100
#
# Epoch 40: val_loss did not improve from 0.00226
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0014 - mae: 0.0247 - val_loss: 0.0025 - val_mae: 0.0351 - learning_rate: 1.2500e-04
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0012 - mae: 0.0245
# Epoch 41: val_loss improved from 0.00226 to 0.00224, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 41: val_loss improved from 0.00226 to 0.00224, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0013 - mae: 0.0247 - val_loss: 0.0022 - val_mae: 0.0332 - learning_rate: 1.2500e-04
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0013 - mae: 0.0247 - val_loss: 0.0022 - val_mae: 0.0332 - learning_rate: 1.2500e-04
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0011 - mae: 0.0236
# Epoch 42: val_loss did not improve from 0.00224
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0013 - mae: 0.0244 - val_loss: 0.0031 - val_mae: 0.0396 - learning_rate: 1.2500e-04
# Epoch 43/100
#
# Epoch 42: val_loss did not improve from 0.00224
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0013 - mae: 0.0244 - val_loss: 0.0031 - val_mae: 0.0396 - learning_rate: 1.2500e-04
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0013 - mae: 0.0235
# Epoch 43: val_loss did not improve from 0.00224
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0014 - mae: 0.0246 - val_loss: 0.0023 - val_mae: 0.0336 - learning_rate: 1.2500e-04
# Epoch 44/100
#
# Epoch 43: val_loss did not improve from 0.00224
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0014 - mae: 0.0246 - val_loss: 0.0023 - val_mae: 0.0336 - learning_rate: 1.2500e-04
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0012 - mae: 0.0224
# Epoch 44: val_loss did not improve from 0.00224
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0013 - mae: 0.0235 - val_loss: 0.0029 - val_mae: 0.0384 - learning_rate: 1.2500e-04
# Epoch 45/100
#
# Epoch 44: val_loss did not improve from 0.00224
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0013 - mae: 0.0235 - val_loss: 0.0029 - val_mae: 0.0384 - learning_rate: 1.2500e-04
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0011 - mae: 0.0226
# Epoch 45: val_loss improved from 0.00224 to 0.00221, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 45: val_loss improved from 0.00224 to 0.00221, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0235 - val_loss: 0.0022 - val_mae: 0.0329 - learning_rate: 1.2500e-04
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0012 - mae: 0.0235 - val_loss: 0.0022 - val_mae: 0.0329 - learning_rate: 1.2500e-04
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0011 - mae: 0.0223
# Epoch 46: val_loss did not improve from 0.00221
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0013 - mae: 0.0242 - val_loss: 0.0023 - val_mae: 0.0333 - learning_rate: 1.2500e-04
# Epoch 47/100
#
# Epoch 46: val_loss did not improve from 0.00221
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0013 - mae: 0.0242 - val_loss: 0.0023 - val_mae: 0.0333 - learning_rate: 1.2500e-04
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0012 - mae: 0.0236
# Epoch 47: val_loss improved from 0.00221 to 0.00217, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 47: val_loss improved from 0.00221 to 0.00217, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0012 - mae: 0.0236 - val_loss: 0.0022 - val_mae: 0.0326 - learning_rate: 6.2500e-05
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0012 - mae: 0.0236 - val_loss: 0.0022 - val_mae: 0.0326 - learning_rate: 6.2500e-05
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0012 - mae: 0.0231
# Epoch 48: val_loss improved from 0.00217 to 0.00195, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
#
# Epoch 48: val_loss improved from 0.00217 to 0.00195, saving model to /home/els4nchez/Videos/TECH/unificacion/modelos/lstm_sentiment_best.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 0.0019 - val_mae: 0.0315 - learning_rate: 6.2500e-05
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 0.0019 - val_mae: 0.0315 - learning_rate: 6.2500e-05
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0014 - mae: 0.0242
# Epoch 49: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0014 - mae: 0.0250 - val_loss: 0.0020 - val_mae: 0.0317 - learning_rate: 6.2500e-05
# Epoch 50/100
#
# Epoch 49: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0014 - mae: 0.0250 - val_loss: 0.0020 - val_mae: 0.0317 - learning_rate: 6.2500e-05
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 9.7149e-04 - mae: 0.0217
# Epoch 50: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0230 - val_loss: 0.0021 - val_mae: 0.0321 - learning_rate: 6.2500e-05
# Epoch 51/100
#
# Epoch 50: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0230 - val_loss: 0.0021 - val_mae: 0.0321 - learning_rate: 6.2500e-05
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0012 - mae: 0.0230
# Epoch 51: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0233 - val_loss: 0.0024 - val_mae: 0.0341 - learning_rate: 6.2500e-05
# Epoch 52/100
#
# Epoch 51: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0233 - val_loss: 0.0024 - val_mae: 0.0341 - learning_rate: 6.2500e-05
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0014 - mae: 0.0236
# Epoch 52: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0237 - val_loss: 0.0024 - val_mae: 0.0339 - learning_rate: 6.2500e-05
# Epoch 53/100
#
# Epoch 52: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0237 - val_loss: 0.0024 - val_mae: 0.0339 - learning_rate: 6.2500e-05
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0012 - mae: 0.0234
# Epoch 53: val_loss did not improve from 0.00195
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0013 - mae: 0.0243 - val_loss: 0.0020 - val_mae: 0.0316 - learning_rate: 6.2500e-05
# Epoch 54/100
#
# Epoch 53: val_loss did not improve from 0.00195
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0013 - mae: 0.0243 - val_loss: 0.0020 - val_mae: 0.0316 - learning_rate: 6.2500e-05
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0015 - mae: 0.0246
# Epoch 54: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0014 - mae: 0.0242 - val_loss: 0.0024 - val_mae: 0.0340 - learning_rate: 3.1250e-05
# Epoch 55/100
#
# Epoch 54: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0014 - mae: 0.0242 - val_loss: 0.0024 - val_mae: 0.0340 - learning_rate: 3.1250e-05
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0011 - mae: 0.0229
# Epoch 55: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0012 - mae: 0.0235 - val_loss: 0.0022 - val_mae: 0.0326 - learning_rate: 3.1250e-05
# Epoch 56/100
#
# Epoch 55: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0012 - mae: 0.0235 - val_loss: 0.0022 - val_mae: 0.0326 - learning_rate: 3.1250e-05
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0011 - mae: 0.0214
# Epoch 56: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 0.0023 - val_mae: 0.0335 - learning_rate: 3.1250e-05
# Epoch 57/100
#
# Epoch 56: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 0.0023 - val_mae: 0.0335 - learning_rate: 3.1250e-05
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0013 - mae: 0.0231
# Epoch 57: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0234 - val_loss: 0.0024 - val_mae: 0.0341 - learning_rate: 3.1250e-05
# Epoch 58/100
#
# Epoch 57: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0013 - mae: 0.0234 - val_loss: 0.0024 - val_mae: 0.0341 - learning_rate: 3.1250e-05
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0012 - mae: 0.0226
# Epoch 58: val_loss did not improve from 0.00195
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0012 - mae: 0.0232 - val_loss: 0.0027 - val_mae: 0.0369 - learning_rate: 3.1250e-05
# Epoch 59/100
#
# Epoch 58: val_loss did not improve from 0.00195
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0012 - mae: 0.0232 - val_loss: 0.0027 - val_mae: 0.0369 - learning_rate: 3.1250e-05
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0011 - mae: 0.0216
# Epoch 59: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0229 - val_loss: 0.0027 - val_mae: 0.0367 - learning_rate: 1.5625e-05
# Epoch 60/100
#
# Epoch 59: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0012 - mae: 0.0229 - val_loss: 0.0027 - val_mae: 0.0367 - learning_rate: 1.5625e-05
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0012 - mae: 0.0233
# Epoch 60: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0012 - mae: 0.0234 - val_loss: 0.0027 - val_mae: 0.0369 - learning_rate: 1.5625e-05
# Epoch 61/100
#
# Epoch 60: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 0.0012 - mae: 0.0234 - val_loss: 0.0027 - val_mae: 0.0369 - learning_rate: 1.5625e-05
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0011 - mae: 0.0223
# Epoch 61: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0012 - mae: 0.0229 - val_loss: 0.0026 - val_mae: 0.0361 - learning_rate: 1.5625e-05
# Epoch 62/100
#
# Epoch 61: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0012 - mae: 0.0229 - val_loss: 0.0026 - val_mae: 0.0361 - learning_rate: 1.5625e-05
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0013 - mae: 0.0233
# Epoch 62: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 0.0024 - val_mae: 0.0338 - learning_rate: 1.5625e-05
# Epoch 63/100
#
# Epoch 62: val_loss did not improve from 0.00195
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 0.0024 - val_mae: 0.0338 - learning_rate: 1.5625e-05
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0011 - mae: 0.0219
# Epoch 63: val_loss did not improve from 0.00195
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0011 - mae: 0.0224 - val_loss: 0.0023 - val_mae: 0.0337 - learning_rate: 1.5625e-05
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 48.
#
# Epoch 63: val_loss did not improve from 0.00195
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0011 - mae: 0.0224 - val_loss: 0.0023 - val_mae: 0.0337 - learning_rate: 1.5625e-05
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 48.
#
# ================================================================================
# ✅ Entrenamiento completado
#
# ================================================================================
# ✅ Entrenamiento completado

# %%
# Visualizar curvas de aprendizaje
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=('Loss (MSE)', 'MAE')
)

# Loss
fig.add_trace(
    go.Scatter(y=history_sentiment.history['loss'], mode='lines', name='Train Loss'),
    row=1, col=1
)
fig.add_trace(
    go.Scatter(y=history_sentiment.history['val_loss'], mode='lines', name='Val Loss'),
    row=1, col=1
)

# MAE
fig.add_trace(
    go.Scatter(y=history_sentiment.history['mae'], mode='lines', name='Train MAE'),
    row=1, col=2
)
fig.add_trace(
    go.Scatter(y=history_sentiment.history['val_mae'], mode='lines', name='Val MAE'),
    row=1, col=2
)

fig.update_xaxes(title_text="Epoch", row=1, col=1)
fig.update_xaxes(title_text="Epoch", row=1, col=2)
fig.update_yaxes(title_text="Loss", row=1, col=1)
fig.update_yaxes(title_text="MAE", row=1, col=2)

fig.update_layout(
    title_text="Curvas de Aprendizaje - Modelo con Sentimiento",
    template='plotly_white',
    height=400
)

fig.show()

print(f"\n📊 Resultados finales:")
print(f"   Train Loss: {history_sentiment.history['loss'][-1]:.6f}")
print(f"   Val Loss: {history_sentiment.history['val_loss'][-1]:.6f}")
print(f"   Train MAE: {history_sentiment.history['mae'][-1]:.6f}")
print(f"   Val MAE: {history_sentiment.history['val_mae'][-1]:.6f}")
# Out:
# 📊 Resultados finales:
#    Train Loss: 0.001136
#    Val Loss: 0.002345
#    Train MAE: 0.022401
#    Val MAE: 0.033658

# %% [markdown]
# ---
#
# ## 1️⃣1️⃣ Evaluación en Conjunto de Test

# %%
# Generar predicciones en test set
print("🔮 Generando predicciones en conjunto de test...\n")

# Modelo Base
y_pred_base_scaled = model_base.predict(X_test_base_seq, verbose=0)
y_pred_base = scaler_target.inverse_transform(y_pred_base_scaled)

# Modelo con Sentimiento
y_pred_sent_scaled = model_sentiment.predict(X_test_sent_seq, verbose=0)
y_pred_sent = scaler_target.inverse_transform(y_pred_sent_scaled)

# Valores reales
y_test_real = scaler_target.inverse_transform(y_test_seq)

print("✅ Predicciones generadas")
print(f"   Shape: {y_pred_base.shape}")
# Out:
# 🔮 Generando predicciones en conjunto de test...
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f7d10536d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ✅ Predicciones generadas
#    Shape: (389, 1)
# ✅ Predicciones generadas
#    Shape: (389, 1)

# %%
# Calcular métricas de evaluación
def calculate_metrics(y_true, y_pred, model_name):
    """
    Calcula métricas de evaluación.
    """
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    # MAPE (Mean Absolute Percentage Error)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    return {
        'model': model_name,
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae,
        'R²': r2,
        'MAPE': mape
    }

# Calcular métricas
metrics_base = calculate_metrics(y_test_real, y_pred_base, 'LSTM Base')
metrics_sent = calculate_metrics(y_test_real, y_pred_sent, 'LSTM + Sentimiento')

# Crear DataFrame de comparación
df_metrics = pd.DataFrame([metrics_base, metrics_sent])

print("📊 COMPARACIÓN DE MODELOS - CONJUNTO DE TEST")
print("="*80)
print(df_metrics.to_string(index=False))
print("="*80)

# Calcular mejora porcentual
mejora_rmse = ((metrics_base['RMSE'] - metrics_sent['RMSE']) / metrics_base['RMSE']) * 100
mejora_mae = ((metrics_base['MAE'] - metrics_sent['MAE']) / metrics_base['MAE']) * 100
mejora_r2 = ((metrics_sent['R²'] - metrics_base['R²']) / abs(metrics_base['R²'])) * 100

print(f"\n🎯 MEJORA CON SENTIMIENTO:")
print(f"   RMSE: {mejora_rmse:+.2f}% ({'✅ mejor' if mejora_rmse > 0 else '❌ peor'})")
print(f"   MAE:  {mejora_mae:+.2f}% ({'✅ mejor' if mejora_mae > 0 else '❌ peor'})")
print(f"   R²:   {mejora_r2:+.2f}% ({'✅ mejor' if mejora_r2 > 0 else '❌ peor'})")
# Out:
# 📊 COMPARACIÓN DE MODELOS - CONJUNTO DE TEST
# ================================================================================
#              model           MSE       RMSE        MAE        R²      MAPE
#          LSTM Base 310905.597806 557.589094 485.183397 -0.932172 15.142114
# LSTM + Sentimiento 314052.328002 560.403719 489.214134 -0.951728 15.281935
# ================================================================================
#
# 🎯 MEJORA CON SENTIMIENTO:
#    RMSE: -0.50% (❌ peor)
#    MAE:  -0.83% (❌ peor)
#    R²:   -2.10% (❌ peor)

# %% [markdown]
# ---
#
# ## 1️⃣2️⃣ Visualización de Predicciones

# %%
# Obtener fechas del test set (ajustadas por seq_length)
test_dates = df_test.index[SEQ_LENGTH:]

# Gráfico comparativo
fig = go.Figure()

# Valores reales
fig.add_trace(go.Scatter(
    x=test_dates,
    y=y_test_real.flatten(),
    mode='lines',
    name='Precio Real',
    line=dict(color='black', width=2)
))

# Predicciones modelo base
fig.add_trace(go.Scatter(
    x=test_dates,
    y=y_pred_base.flatten(),
    mode='lines',
    name='LSTM Base',
    line=dict(color='blue', width=1.5, dash='dash')
))

# Predicciones modelo con sentimiento
fig.add_trace(go.Scatter(
    x=test_dates,
    y=y_pred_sent.flatten(),
    mode='lines',
    name='LSTM + Sentimiento',
    line=dict(color='red', width=1.5, dash='dot')
))

fig.update_layout(
    title='🔮 Predicciones vs Valores Reales - Conjunto de Test',
    xaxis_title='Fecha',
    yaxis_title='Precio de Cierre (USD)',
    template='plotly_white',
    height=600,
    hovermode='x unified'
)

fig.show()

# %%
# Gráfico de errores (residuos)
errors_base = y_test_real.flatten() - y_pred_base.flatten()
errors_sent = y_test_real.flatten() - y_pred_sent.flatten()

fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=('Residuos - LSTM Base', 'Residuos - LSTM + Sentimiento'),
    vertical_spacing=0.1
)

# Modelo Base
fig.add_trace(
    go.Scatter(x=test_dates, y=errors_base, mode='lines', name='Residuos Base', line=dict(color='blue')),
    row=1, col=1
)
fig.add_hline(y=0, line_dash="dash", line_color="gray", row=1, col=1)

# Modelo con Sentimiento
fig.add_trace(
    go.Scatter(x=test_dates, y=errors_sent, mode='lines', name='Residuos Sent', line=dict(color='red')),
    row=2, col=1
)
fig.add_hline(y=0, line_dash="dash", line_color="gray", row=2, col=1)

fig.update_xaxes(title_text="Fecha", row=2, col=1)
fig.update_yaxes(title_text="Error (USD)", row=1, col=1)
fig.update_yaxes(title_text="Error (USD)", row=2, col=1)

fig.update_layout(
    title_text="Análisis de Residuos",
    template='plotly_white',
    height=600,
    showlegend=False
)

fig.show()

print(f"\n📊 Estadísticas de errores:")
print(f"\nModelo Base:")
print(f"   Media: {errors_base.mean():.2f} USD")
print(f"   Std: {errors_base.std():.2f} USD")
print(f"   Min: {errors_base.min():.2f} USD")
print(f"   Max: {errors_base.max():.2f} USD")

print(f"\nModelo con Sentimiento:")
print(f"   Media: {errors_sent.mean():.2f} USD")
print(f"   Std: {errors_sent.std():.2f} USD")
print(f"   Min: {errors_sent.min():.2f} USD")
print(f"   Max: {errors_sent.max():.2f} USD")
# Out:
# 📊 Estadísticas de errores:
#
# Modelo Base:
#    Media: 485.18 USD
#    Std: 274.78 USD
#    Min: 92.53 USD
#    Max: 1376.94 USD
#
# Modelo con Sentimiento:
#    Media: 489.21 USD
#    Std: 273.35 USD
#    Min: 88.92 USD
#    Max: 1373.03 USD

# %% [markdown]
# ---
#
# ## 1️⃣3️⃣ Exportación de Resultados

# %%
# Exportar predicciones
df_predictions = pd.DataFrame({
    'fecha': test_dates,
    'precio_real': y_test_real.flatten(),
    'pred_base': y_pred_base.flatten(),
    'pred_sentiment': y_pred_sent.flatten(),
    'error_base': errors_base,
    'error_sentiment': errors_sent
})

archivo_pred = DATA_PROCESADO_DIR / 'predicciones_lstm.csv'
df_predictions.to_csv(archivo_pred, index=False)
print(f"✅ Predicciones exportadas: {archivo_pred}")

# Exportar métricas
resultados = {
    'configuracion': {
        'seq_length': SEQ_LENGTH,
        'train_size': len(df_train),
        'val_size': len(df_val),
        'test_size': len(df_test),
        'features_base': features_base,
        'features_sentiment': features_sentiment,
        'arquitectura': '256-128-64',
        'dropout': 0.2,
        'optimizer': 'Adam',
        'learning_rate': 0.001
    },
    'metricas_test': {
        'base': metrics_base,
        'sentiment': metrics_sent,
        'mejora_porcentual': {
            'rmse': float(mejora_rmse),
            'mae': float(mejora_mae),
            'r2': float(mejora_r2)
        }
    },
    'historia_entrenamiento': {
        'base': {
            'epochs': len(history_base.history['loss']),
            'final_train_loss': float(history_base.history['loss'][-1]),
            'final_val_loss': float(history_base.history['val_loss'][-1])
        },
        'sentiment': {
            'epochs': len(history_sentiment.history['loss']),
            'final_train_loss': float(history_sentiment.history['loss'][-1]),
            'final_val_loss': float(history_sentiment.history['val_loss'][-1])
        }
    }
}

archivo_resultados = DATA_PROCESADO_DIR / 'resultados_lstm.json'
with open(archivo_resultados, 'w', encoding='utf-8') as f:
    json.dump(resultados, f, indent=2, ensure_ascii=False)

print(f"✅ Resultados exportados: {archivo_resultados}")

# Guardar modelos finales
model_base.save(MODELOS_DIR / 'lstm_base_final.keras')
model_sentiment.save(MODELOS_DIR / 'lstm_sentiment_final.keras')
print(f"✅ Modelos guardados en: {MODELOS_DIR}")
# Out:
# ✅ Predicciones exportadas: /home/els4nchez/Videos/TECH/unificacion/datos_procesados/predicciones_lstm.csv
# ✅ Resultados exportados: /home/els4nchez/Videos/TECH/unificacion/datos_procesados/resultados_lstm.json
# ✅ Modelos guardados en: /home/els4nchez/Videos/TECH/unificacion/modelos
# ✅ Modelos guardados en: /home/els4nchez/Videos/TECH/unificacion/modelos

# %% [markdown]
# ---
#
# ## 1️⃣4️⃣ Resumen Ejecutivo

# %%
print("""
╔════════════════════════════════════════════════════════════════════════╗
║         🤖 RESUMEN EJECUTIVO - MODELO LSTM INTEGRADO                   ║
╠════════════════════════════════════════════════════════════════════════╣
║                                                                        ║
║  ✅ MODELOS ENTRENADOS Y EVALUADOS                                     ║
║                                                                        ║
║  📊 CONFIGURACIÓN:                                                     ║
║                                                                        ║""")

print(f"║  • Arquitectura: 256-128-64 LSTM units                            ║")
print(f"║  • Dropout: 0.2 por capa                                          ║")
print(f"║  • Secuencias: {SEQ_LENGTH} días de lookback                                  ║")
print(f"║  • Train/Val/Test: 60%/20%/20%                                    ║")

print("""
║                                                                        ║
║  📈 RESULTADOS EN TEST SET:                                            ║
║                                                                        ║""")

print(f"║  🔹 MODELO BASE (sin sentimiento):                                 ║")
print(f"║     RMSE: ${metrics_base['RMSE']:7.2f}                                            ║")
print(f"║     MAE:  ${metrics_base['MAE']:7.2f}                                            ║")
print(f"║     R²:   {metrics_base['R²']:7.4f}                                            ║")
print(f"║     MAPE: {metrics_base['MAPE']:6.2f}%                                             ║")

print("""
║                                                                        ║""")

print(f"║  🔸 MODELO CON SENTIMIENTO:                                        ║")
print(f"║     RMSE: ${metrics_sent['RMSE']:7.2f}                                            ║")
print(f"║     MAE:  ${metrics_sent['MAE']:7.2f}                                            ║")
print(f"║     R²:   {metrics_sent['R²']:7.4f}                                            ║")
print(f"║     MAPE: {metrics_sent['MAPE']:6.2f}%                                             ║")

print("""
║                                                                        ║
║  🎯 MEJORA CON SENTIMIENTO:                                            ║
║                                                                        ║""")

print(f"║     RMSE: {mejora_rmse:+6.2f}% ({'✅ MEJOR' if mejora_rmse > 0 else '❌ PEOR':10s})                            ║")
print(f"║     MAE:  {mejora_mae:+6.2f}% ({'✅ MEJOR' if mejora_mae > 0 else '❌ PEOR':10s})                            ║")
print(f"║     R²:   {mejora_r2:+6.2f}% ({'✅ MEJOR' if mejora_r2 > 0 else '❌ PEOR':10s})                            ║")

print("""
║                                                                        ║
║  📂 ARCHIVOS GENERADOS:                                                ║
║                                                                        ║
║  • predicciones_lstm.csv                                              ║
║  • resultados_lstm.json                                               ║
║  • lstm_base_final.keras                                              ║
║  • lstm_sentiment_final.keras                                         ║
║                                                                        ║
║  ➡️  SIGUIENTE PASO:                                                   ║
║     Notebook 08 - Síntesis y Resultados para Paper Científico        ║
║                                                                        ║
╚════════════════════════════════════════════════════════════════════════╝
""")

# Conclusión final
if mejora_rmse > 0 and mejora_mae > 0:
    print("\n✅ CONCLUSIÓN: Los features de sentimiento MEJORAN las predicciones del modelo LSTM.")
    print("   El análisis de sentimientos de noticias tiene valor predictivo para el precio del oro.")
elif mejora_rmse > 2 or mejora_mae > 2:
    print("\n⚠️  CONCLUSIÓN: Los features de sentimiento muestran mejora moderada.")
    print("   El análisis de sentimientos aporta información, pero no es determinante.")
else:
    print("\n❌ CONCLUSIÓN: Los features de sentimiento NO mejoran significativamente las predicciones.")
    print("   Los indicadores técnicos tradicionales son suficientes para este modelo.")
# Out:
# ╔════════════════════════════════════════════════════════════════════════╗
# ║         🤖 RESUMEN EJECUTIVO - MODELO LSTM INTEGRADO                   ║
# ╠════════════════════════════════════════════════════════════════════════╣
# ║                                                                        ║
# ║  ✅ MODELOS ENTRENADOS Y EVALUADOS                                     ║
# ║                                                                        ║
# ║  📊 CONFIGURACIÓN:                                                     ║
# ║                                                                        ║
# ║  • Arquitectura: 256-128-64 LSTM units                            ║
# ║  • Dropout: 0.2 por capa                                          ║
# ║  • Secuencias: 60 días de lookback                                  ║
# ║  • Train/Val/Test: 60%/20%/20%                                    ║
#
# ║                                                                        ║
# ║  📈 RESULTADOS EN TEST SET:                                            ║
# ║                                                                        ║
# ║  🔹 MODELO BASE (sin sentimiento):                                 ║
# ║     RMSE: $ 557.59                                            ║
# ║     MAE:  $ 485.18                                            ║
# ║     R²:   -0.9322                                            ║
# ║     MAPE:  15.14%                                             ║
#
# ║                                                                        ║
# ║  🔸 MODELO CON SENTIMIENTO:                                        ║
# ║     RMSE: $ 560.40                                            ║
# ║     MAE:  $ 489.21                                            ║
# ║     R²:   -0.9517                                            ║
# ║     MAPE:  15.28%                                             ║
#
# ║                                                                        ║
# ║  🎯 MEJORA CON SENTIMIENTO:                                            ║
# ║                                                                        ║
# ║     RMSE:  -0.50% (❌ PEOR    )                            ║
# ║     MAE:   -0.83% (❌ PEOR    )                            ║
# ║     R²:    -2.10% (❌ PEOR    )                            ║
#
# ║                                                                        ║
# ║  📂 ARCHIVOS GENERADOS:                                                ║
# ║                                                                        ║
# ║  • predicciones_lstm.csv                                              ║
# ║  • resultados_lstm.json                                               ║
# ║  • lstm_base_final.keras                                              ║
# ║  • lstm_sentiment_final.keras                                         ║
# ║                                                                        ║
# ║  ➡️  SIGUIENTE PASO:                                                   ║
# ║     Notebook 08 - Síntesis y Resultados para Paper Científico        ║
# ║                                                                        ║
# ╚════════════════════════════════════════════════════════════════════════╝
#
#
# ❌ CONCLUSIÓN: Los features de sentimiento NO mejoran significativamente las predicciones.
#    Los indicadores técnicos tradicionales son suficientes para este modelo.
